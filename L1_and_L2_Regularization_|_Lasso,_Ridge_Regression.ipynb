# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/MachineLearningBasics/blob/ClassificationModels/L1_and_L2_Regularization_%7C_Lasso%2C_Ridge_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Import libraries in the system
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/MyDrive/py-master/ML/16_regularization/'
# Out:
# 'L1 and L2 Regularization.ipynb'   Melbourne_housing_FULL.csv

# %%
# Read data in pandas dataframe
df = pd.read_csv('/content/drive/MyDrive/py-master/ML/16_regularization/Melbourne_housing_FULL.csv')
df.head()
# Out:
#        Suburb             Address  ...             Regionname Propertycount
# 0  Abbotsford       68 Studley St  ...  Northern Metropolitan        4019.0
# 1  Abbotsford        85 Turner St  ...  Northern Metropolitan        4019.0
# 2  Abbotsford     25 Bloomburg St  ...  Northern Metropolitan        4019.0
# 3  Abbotsford  18/659 Victoria St  ...  Northern Metropolitan        4019.0
# 4  Abbotsford        5 Charles St  ...  Northern Metropolitan        4019.0
#
# [5 rows x 21 columns]

# %%
df.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
df.shape
# Out:
# (34857, 21)

# %%
cols_to_use =['Suburb','Rooms','Type','Method','SellerG','Regionname','Propertycount','Distance',
              'Bedroom2','Bathroom','CouncilArea','Car','Landsize','BuildingArea','Price']

# %%
df1= df[cols_to_use]

# %%
df1.head()
# Out:
#        Suburb  Rooms Type Method  ...  Car Landsize  BuildingArea      Price
# 0  Abbotsford      2    h     SS  ...  1.0    126.0           NaN        NaN
# 1  Abbotsford      2    h      S  ...  1.0    202.0           NaN  1480000.0
# 2  Abbotsford      2    h      S  ...  0.0    156.0          79.0  1035000.0
# 3  Abbotsford      3    u     VB  ...  1.0      0.0           NaN        NaN
# 4  Abbotsford      3    h     SP  ...  0.0    134.0         150.0  1465000.0
#
# [5 rows x 15 columns]

# %%
df1.shape
# Out:
# (34857, 15)

# %%
df1.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# Bedroom2         0
# Bathroom         0
# CouncilArea      0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
cols_to_fillzero=['Propertycount','Distance','Bedroom2','Bathroom','Car']
df1[cols_to_fillzero]=df1[cols_to_fillzero].fillna(0)

# %%
df1['Landsize']=df1['Landsize'].fillna(df.Landsize.mean())
df1['BuildingArea']=df1['BuildingArea'].fillna(df.BuildingArea.mean())

# %%
df1.dropna(inplace=True)

# %%
df1 = pd.get_dummies(df1,drop_first=True)
df1.head()
# Out:
#    Rooms  ...  CouncilArea_Yarra Ranges Shire Council
# 1      2  ...                                       0
# 2      2  ...                                       0
# 4      3  ...                                       0
# 5      3  ...                                       0
# 6      4  ...                                       0
#
# [5 rows x 745 columns]

# %%
x=df1.drop('Price',axis=1)
y=df1.Price
x.shape
# Out:
# (27244, 744)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3, random_state=2)
len(xtrain)
# Out:
# 19070

# %%
len(xtest)
# Out:
# 8174

# %%
# Start with regular linear regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain,ytrain)
model.score(xtest,ytest)
# Out:
# 0.13853683161569574

# %%
model.score(xtrain,ytrain)
# Out:
# 0.6827792395792723

# %%
# L1 regularization

from sklearn import linear_model
model = linear_model.Lasso(alpha=50,max_iter=100,tol=0.1)
model.fit(xtrain,ytrain)
model.score(xtest,ytest)
# Out:
# 0.6636111369404489

# %%
# L2 Regularization
 
from sklearn import linear_model
model = linear_model.Ridge(alpha=50,max_iter=100,tol=0.1)
model.fit(xtrain,ytrain)
model.score(xtest,ytest)
# Out:
# 0.6670848945194958
